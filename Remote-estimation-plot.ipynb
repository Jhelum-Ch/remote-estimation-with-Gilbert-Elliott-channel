# %%
#push!(LOAD_PATH, pwd())
using Plots
#gr()
#using Gadfly
#using PyPlot

# %%
@time include("RE_Q_value_iter_inf_hor.jl")
# Out:
#  53.569926 seconds (1.35 G allocations: 23.313 GB, 2.96% gc time)

# %%
#draw(SVG("output.svg", 6inch, 3inch), plot(X, V))

plot(X, V_beta, grid=false)

# %% [markdown]
# threshold[1:T]

# %%
plot(g_beta[1][395:602]-g_beta[2][395:602])
